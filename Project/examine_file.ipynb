# %%
import pandas as pd

df = pd.read_csv(r"C:\COSC 301\COSC 301 Project\stack-overflow-developer-survey-2024 (1)\survey_results_public.csv")

# %%
import json
list_columns = list(df.columns)
with open('columns.json', 'w') as file:
    json.dump(list_columns, file, indent = 2)

# %%
subset = df.loc[:, [
    "Country",
    "YearsCodePro",
    "EdLevel",
    "DevType",
    "LanguageHaveWorkedWith",
    "Employment",
    "ConvertedCompYearly"
]]

subset.to_csv('subset.csv', index = False)
